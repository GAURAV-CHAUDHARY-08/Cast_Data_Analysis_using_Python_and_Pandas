# %%
import pandas as pd
import matplotlib as mp
cast = pd.read_csv(r"C:\Users\gc531\Downloads\cast.csv")
cast
# Out:
#                                      title  year                         name  \
# 0                          Suuri illusioni  1985                       Homo $
# 1           Gangsta Rap: The Glockumentary  2007                    Too $hort
# 2                        Menace II Society  1993                    Too $hort
# 3        Porndogs: The Adventures of Sadie  2009                    Too $hort
# 4                       Stop Pepper Palmer  2014                    Too $hort
# ...                                    ...   ...                          ...
# 3311642                     Stuttur Frakki  1993    Sveinbj?rg ??rhallsd?ttir
# 3311643                            Foxtrot  1988            Lilja ??risd?ttir
# 3311644   Niceland (Population. 1.000.002)  2004    Sigr??ur J?na ??risd?ttir
# 3311645                       U.S.S.S.S...  2003  Krist?n Andrea ??r?ard?ttir
# 3311646                  Bye Bye Blue Bird  1999                 Rosa ? R?gvu
#
# ...

# %% [markdown]
# # Q1 What are the ten most common movie names of all time?

# %%
'''A = cast.groupby("title").count().sort_values(by = "year",ascending = False).head(10)
Ab = A.rename(columns={'title':'Most Common Movies'})
Abc = Ab.iloc[ : , :0]
Abc'''
cast.title.value_counts().head(10)
# Out:
# Around the World in Eighty Days       1300
# 7 cajas                                689
# Thelma                                 580
# The Ten Commandments                   529
# The Eschatrilogy: Book of the Dead     517
# A Broken Code                          477
# Welcome to Essex                       443
# Stuck on You                           438
# The Dark Knight Rises                  429
# The Buccaneer                          428
# Name: title, dtype: int64

# %% [markdown]
# # Q2 Which three years of the 1930s saw the most films released?

# %%
cast[(cast.year >= 1930) & (cast.year <= 1939)].year.value_counts().head(3)
# Out:
# 1937    27022
# 1936    25381
# 1938    24755
# Name: year, dtype: int64

# %% [markdown]
# # Q3 Plot the number of films that have been released each decade over the history of cinema.

# %%
#cast.groupby((cast.year//10)*10).sum()
cast.groupby(cast.year//10*10).title.count().plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# # Q4 Plot the number of "Hamlet" films made each decade.

# %%
cast[cast.title == "Hamlet"].groupby(cast.year//10*10).title.count().plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# # Q5 Plot the number of "Rustler" characters in each decade of the history of film.

# %%
cast[cast.character == "Rustler"].groupby(cast.year//10*10).title.count().plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# # Q6 Plot the number of "Hamlet" characters each decade.

# %%
cast[cast.character == "Hamlet"].groupby(cast.year//10*10).title.count().plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# # Q7 What are the 11 most common character names in movie history?

# %%
cast.character.value_counts().head(11).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q8 Who are the 10 people most often credited as "Herself" in film history?

# %%
#If the character name is herself.
cast[cast.character == "Herself"].name.value_counts().head(10)
# Out:
# Joyce Brothers        14
# Queen Elizabeth II    11
# Margaret Thatcher      8
# Joan Rivers            7
# Mary Jo Pehl           7
# Juhi Chawla            5
# Lili?n Garc?a          5
# Chris Evert            5
# Rekha                  5
# Kareena Kapoor         5
# Name: name, dtype: int64

# %%
#If the character name and helself name is same.
cast[cast.character == cast.name].name.value_counts().head(10)
# Out:
# Gene Autry           88
# Roy Rogers           69
# Trigger              47
# Tarzan               45
# Smiley Burnette      40
# Jimmy Wakely         28
# Larry King           23
# Johnny Mack Brown    19
# Sunset Carson        18
# Jay Leno             18
# Name: name, dtype: int64

# %%
#If the type of character is actress.
cast[cast.type == "actress" ].name.value_counts().head(10)
# Out:
# Bess Flowers      807
# Mary Gordon       279
# Aruna Irani       270
# Helen             234
# Gertrude Astor    229
# Minerva Urecal    227
# Leonor G?mez      206
# Ann Doran         201
# Frances Morris    201
# Claire Du Brey    197
# Name: name, dtype: int64

# %% [markdown]
# # Q9 Who are the 10 people most often credited as "Himself" in film history?

# %%
#If the character name is himself.
cast[cast.character == "Himself"].name.value_counts().head(10)
# Out:
# Adolf Hitler             93
# Richard Nixon            39
# Ronald Reagan            31
# John F. Kennedy          26
# Ron Jeremy               24
# Franklin D. Roosevelt    20
# Bill Clinton             20
# Winston Churchill        20
# George W. Bush           20
# Martin Luther King       19
# Name: name, dtype: int64

# %%
#If the character name and himself name is same.
cast[cast.character == cast.name].name.value_counts().head(10)
# Out:
# Gene Autry           88
# Roy Rogers           69
# Trigger              47
# Tarzan               45
# Smiley Burnette      40
# Jimmy Wakely         28
# Larry King           23
# Johnny Mack Brown    19
# Sunset Carson        18
# Jay Leno             18
# Name: name, dtype: int64

# %%
#If the type of character is actor.
cast[cast.type == "actor" ].name.value_counts().head(10)
# Out:
# Herman Hack        666
# Sam (II) Harris    620
# Lee Phelps         613
# Frank O'Connor     598
# Harold Miller      579
# Tom London         559
# Frank Ellis        538
# Franklyn Farnum    536
# Larry Steers       532
# Bud Osborne        510
# Name: name, dtype: int64

# %% [markdown]
# # Q10 Which actors or actresses appeared in the most movies in the year 1945?

# %%
#cast[cast.year == 1945].groupby("type").name.value_counts().head(10)
cast[cast.year == 1945].groupby(['type','name']).count().sort_values(by='title',ascending=False).head(10)
# Out:
#                           title  year  character   n
# type    name
# actor   Emmett Vogan         39    39         39  14
#         Sam (II) Harris      30    30         30   0
# actress Bess Flowers         28    28         28   0
# actor   Harold Miller        28    28         28   0
#         Nolan Leary          27    27         27   0
#         Frank O'Connor       26    26         26   1
#         Edmund Cobb          24    24         24   5
#         Charles Sullivan     24    24         24   0
#         Tom London           24    24         24  17
#         Franklyn Farnum      24    24         24   0

# %% [markdown]
# # Q11 Which actors or actresses appeared in the most movies in the year 1985?

# %%
#cast[cast.year == 1985].groupby("type").name.value_counts().head(1)
cast[cast.year == 1985].groupby(['type','name']).count().sort_values(by='title',ascending=False).head(10)
# Out:
#                           title  year  character   n
# type    name
# actor   Shakti Kapoor        19    19         19  10
#         Mammootty            17    17         17  17
# actress Sukumari             16    16         16  16
# actor   Lou Scheimer         15    15         15  15
# actress Aruna Irani          14    14         14  11
# actor   Rajesh Khanna        13    13         13  12
#         Raj Babbar           13    13         13  10
#         Deven Verma          13    13         13  12
#         Mohanlal             13    13         13  13
#         Satyendra Kapoor     12    12         12   6

# %% [markdown]
# # Q12 Plot how many roles Mammootty has played in each year of his career.

# %%
cast[cast.name == "Mammootty"].groupby("year").character.count().plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# # Q13 What are the 10 most frequent roles that start with the phrase "Patron in"?

# %%
cast[cast.character.str.contains('Patron in')].character.value_counts().head(10)
# Out:
# Patron in Frisky Rabbit         16
# Patron in Chinese Restaurant     9
# Patron in the Coffee House       9
# Patron in Billiard Parlor        5
# Patron in Bar                    4
# Patron in Restaurant             3
# Patron in Club                   3
# Patron in cabaret                3
# Patron in restaurant             3
# Patron in Quiet Bar              2
# Name: character, dtype: int64

# %% [markdown]
# # Q14 What are the 10 most frequent roles that start with the word "Science"?

# %%
cast[cast.character.str.startswith('Science')].character.value_counts().head(10)
# Out:
# Science Teacher         53
# Science Student          8
# Science Fair Student     8
# Science Fair Judge       6
# Science Club Member      5
# Science Reporter         5
# Science Kid              4
# Science Promo Cadet      4
# Science Officer          3
# Science Fair Kid         3
# Name: character, dtype: int64

# %% [markdown]
# # Q15 Plot the n-values of the roles that Judi Dench has played over her career.

# %%
cast[cast.name == "Judi Dench"].set_index("character").n.plot.bar()
#cast[cast.name =='Judi Dench'].iloc[:,[2,4,5]].nunique()
# Out:
# <AxesSubplot:xlabel='character'>

# %% [markdown]
# # Q16 Plot the n-values of Cary Grant's roles through his career.

# %%
cast[cast.name == "Cary Grant"].set_index("character").n.plot.bar()
# Out:
# <AxesSubplot:xlabel='character'>

# %% [markdown]
# # Q17 Plot the n-value of the roles that Sidney Poitier has acted over the years.

# %%
cast[cast.name == "Sidney Poitier"].set_index("character").n.plot.bar()
# Out:
# <AxesSubplot:xlabel='character'>

# %% [markdown]
# # Q18 How many leading (n=1) roles were available to actors, and how many to actresses, in the 1950s?

# %%
cast[(cast.year >= 1950) & (cast.year <= 1959) & (cast.n == 1)].groupby("type").character.nunique()
# Out:
# type
# actor      5743
# actress    2533
# Name: character, dtype: int64

# %% [markdown]
# # Q19 How many supporting (n=2) roles were available to actors, and how many to actresses, in the 1950s?

# %%
cast[(cast.year >= 1950) & (cast.year <= 1959) & (cast.n == 2)].groupby("type").character.nunique()
# Out:
# type
# actor      3981
# actress    3887
# Name: character, dtype: int64
